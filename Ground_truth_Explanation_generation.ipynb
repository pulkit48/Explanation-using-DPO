# %% [markdown]
# <a href="https://colab.research.google.com/github/pulkit48/Explanation-using-DPO/blob/main/Ground_truth_Explanation_generation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install openai httpx==0.27.2
# Out:
# Requirement already satisfied: openai in /usr/local/lib/python3.10/dist-packages (1.54.5)
# Requirement already satisfied: httpx==0.27.2 in /usr/local/lib/python3.10/dist-packages (0.27.2)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx==0.27.2) (3.7.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx==0.27.2) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx==0.27.2) (1.0.7)
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from httpx==0.27.2) (3.10)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx==0.27.2) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx==0.27.2) (0.14.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from openai) (0.8.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from openai) (2.10.3)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.10/dist-packages (from openai) (4.66.6)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /usr/local/lib/python3.10/dist-packages (from openai) (4.12.2)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx==0.27.2) (1.2.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.1 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (2.27.1)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
df=pd.read_csv('/content/drive/MyDrive/final_df_all.csv',index_col=False)
# temp=df['main_news']
df['News_description_updated']=[None]*df.shape[0]
# temp_list_=[]
# for i in range(df.shape[0]):
#     temp_list_.append(df['main_news'][i][:-1].replace('[\n    Main news:',''))
# df['main_news']=temp_list_

# %%
# # # url='https://drive.google.com/file/d/1NVHcInAW_W7PXC88Hq9sZtP2bipUZgO2/view?usp=sharing'
# url = f'https://drive.google.com/uc?id=1NVHcInAW_W7PXC88Hq9sZtP2bipUZgO2'

# df1=pd.read_csv(url,index_col=False)

# %%
# df['result']=df1.Results

# %%
df.head()
# Out:
#                                     News_description  \
# 0  लोकसभा चुनाव 2024 के लिए चुनाव आयोग द्वारा घोष...
# 1  प्रधानमंत्री नरेंद्र मोदी को लेकर अब कर्नाटक क...
# 2  कांग्रेस नेता राहुल गांधी का एक वीडियो सोशल मी...
# 3  यूपी में हुए राज्यसभा चुनाव में भाजपा ने एक ती...
# 4  तृणमूल कांग्रेस नेता और निष्कासित लोकसभा सांसद...
#
#                                            main_news  \
# 0   प्रधानमंत्री नरेंद्र मोदी ने आंध्र प्रदेश के ...
# 1   कर्नाटक के मंत्री और कांग्रेस नेता शिवराज एस ...
# 2   कांग्रेस नेता राहुल गांधी का एक वीडियो में उन...
# 3   यूपी में राज्यसभा चुनाव के दौरान भाजपा ने समा...
# 4   तृणमूल कांग्रेस नेता महुआ मोइत्रा को प्रवर्तन...
#
#                                          explain_gpt  \
# 0  इस समाचार को देखकर यह कहना उचित होगा कि यह **व...
# 1  यह समाचार लेख असत्य प्रतीत होता है। पहले, इस त...
# 2  इस समाचार को में **वास्तविक** मानता हूँ। इसकी ...
# 3  यह समाचार **वास्तविक** प्रतीत होता है। इसकी पु...
# 4  यह समाचार पत्रिका का शीर्षक और विषय विशेष रूप ...
#
#                                       explain_gemini  index  \
# 0  यह समाचार वास्तविक प्रतीत होता है।  इसमें प्रध...      0
# 1  यह खबर असली लगती है।  इसमें कर्नाटक के एक मंत्...      1
# 2  यह समाचार वास्तविक लगता है।  लेख में राहुल गां...      2
# 3  यह समाचार लेख वास्तविक लगता है।  इसमें राज्यसभ...      3
# 4  दी गयी खबर की प्रकृति को देखते हुए, यह संभवतः ...      4
#
#                              explain_mistral_updated News_description_updated  \
# 0  यह समाचार **झूठा** है क्योंकि इसमें कई व्याकरण...                     None
# 1  The article's authenticity is in question. It ...                     None
# 2  यह समाचार लेख संभवतः फर्जी है क्योंकि यह सरल औ...                     None
# 3  यह समाचार लेख भारत के उत्तर हिस्से में मौसम मे...                     None
# 4  इस समाचार लेख में 2022 में गुजरात विधान सभा चु...                     None
#
#   result
# 0     सच
# 1     सच
# 2    झूठ
# 3     सच
# 4     सच

# %%
import os
import openai
# os.environ['OPENAI_API_KEY'] = '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'
os.environ['OPENAI_API_KEY']='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'
openai.api_key = os.getenv('OPENAI_API_KEY')

flag=0

import time

def generate_response(article, model="gpt-4o-mini"):
    # Introducing a delay of 2 seconds (you can adjust this as needed)
    time.sleep(5)

    user_prompt=f'''I will provide you with an article containing a verified news story along with related information.
    Your task is to rewrite the article as an explanation, explicitly emphasizing that the news is true and using only
    the content provided in the article to substantiate this claim. You must not remove or add any information beyond what is provided.
    Don't use extra newline characters. Use only the format that inputted article has.
    It's mendatory to add sentences that emphasize that the news is true. Even if possible add such sentences mutiple time.
    Restrict to provide the output in Hindi Language Only.
    Input:{article}

    Output:
    '''

    response = openai.chat.completions.create(
        model=model,
        messages=[
            {"role": "system", "content": "You are a helpful assistant."},
            {"role": "user", "content": user_prompt}
        ]
    )

    return response.choices[0].message.content.replace(user_prompt,"" ).replace('\n\n\n',"")

flag=0
for i in range(0,df.shape[0]):
    if df.result[i]!='सच':
      df.loc[i, 'News_description_updated']=df.loc[i, 'News_description']
      continue
    article = df.News_description[i]
    if df.loc[i, 'News_description_updated'] is not None :
    # if not isinstance(df1.loc[i, 'News_description_updated'],float):
      continue
    response=generate_response(article)
    # Save the response to the DataFrame
    df.loc[i, 'News_description_updated'] = response

    # Save intermediate results to a CSV
    df.to_csv('/content/drive/MyDrive/final_df_all.csv', index=False)

    # Optionally, print the response for the first row

    # if i%10 == 0:

    #     # print(article)
    #     print(response)


    print(f"Processed article {i + 1}/{df.shape[0]}")
    # break
# Output the final DataFrame
# print(df)
