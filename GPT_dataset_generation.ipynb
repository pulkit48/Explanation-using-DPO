# %% [markdown]
# <a href="https://colab.research.google.com/github/pulkit48/Explanation-using-DPO/blob/main/GPT_dataset_generation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
df=pd.read_csv('/content/drive/MyDrive/final_df_final.csv',index_col=False)
# temp=df['main_news']
df['explain_llama']=[None]*df.shape[0]
# temp_list_=[]
# for i in range(df.shape[0]):
#     temp_list_.append(df['main_news'][i][:-1].replace('[\n    Main news:',''))
# df['main_news']=temp_list_

# %%
# !pip install openai httpx==0.27.2

# %%
df.head()
# Out:
#    Unnamed: 0                                   News_description  \
# 0           0  लोकसभा चुनाव 2024 के लिए चुनाव आयोग द्वारा घोष...
# 1           1  प्रधानमंत्री नरेंद्र मोदी को लेकर अब कर्नाटक क...
# 2           2  कांग्रेस नेता राहुल गांधी का एक वीडियो सोशल मी...
# 3           3  यूपी में हुए राज्यसभा चुनाव में भाजपा ने एक ती...
# 4           4  तृणमूल कांग्रेस नेता और निष्कासित लोकसभा सांसद...
#
#                                            main_news  \
# 0   प्रधानमंत्री नरेंद्र मोदी ने आंध्र प्रदेश के ...
# 1   कर्नाटक के मंत्री और कांग्रेस नेता शिवराज एस ...
# 2   कांग्रेस नेता राहुल गांधी का एक वीडियो में उन...
# 3   यूपी में राज्यसभा चुनाव के दौरान भाजपा ने समा...
# 4   तृणमूल कांग्रेस नेता महुआ मोइत्रा को प्रवर्तन...
#
#                                        explain_llama
# 0  यह समाचार **सच्चा** प्रतीत होता है। इस समाचार ...
# 1  यह समाचार **विश्वासनीय** प्रतीत होता है। इस प्...
# 2  यह समाचार वास्तव में वास्तविक प्रतीत होता है। ...
# ...

# %%
import os
import openai
os.environ['OPENAI_API_KEY'] = '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'
openai.api_key = os.getenv('OPENAI_API_KEY')

flag=0

def generate_response(article, model="gpt-4o-mini"):

    user_prompt = f'''Task: I will provide you with a news article. Your task is to do the following:

1. Predict whether the news is **fake** or **real**.
2. Provide a detailed explanation for your prediction.

The explanation and classification must be provided **only in Hindi**. Ensure that your response is written as paragraphs, with no bullet points, numbering, or any other format. The explanation should flow naturally in paragraph form and should be detailed enough to justify your prediction. Do not include any extra information or text beyond your explanation.

Here is the news article: {article}

Answer in the form of a detailed paragraph:
'''


    response = openai.chat.completions.create(
        model="gpt-4o-mini",
        messages=[
            {"role": "system", "content": "You are a helpful assistant."},
            {"role": "user", "content": user_prompt}
        ]
    )

    return response.choices[0].message.content


flag=0
for i in range(df.shape[0]):
    article = df.main_news[i]
    if df.loc[i, 'explain_llama'] is not None:
      continue
    response=generate_response(article)
    # Save the response to the DataFrame
    df.loc[i, 'explain_llama'] = response

    # Save intermediate results to a CSV
    df.to_csv('/content/drive/MyDrive/final_df_final.csv', index=False)

    # Optionally, print the response for the first row

    if flag == 0:
        flag=1
        print(response)

    print(f"Processed article {i + 1}/{df.shape[0]}")

# Output the final DataFrame
print(df)
